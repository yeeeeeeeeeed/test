# %% [markdown]
# ## Quiz 6
#
# ---
#
# ### q1.py — 3의 배수 / 5의 배수 개수 세기
#
# **문제**
# 1~100 범위의 random number 10개 리스트를 만들고, 그 중 3의 배수 개수와 5의 배수 개수를 출력하시오.
#
# **힌트 (슬라이드 제공)**
# ```python
# import random
#
# # while (반복조건):
# #     num = random.randint(1, 100)
# ```
#
# **실행 예시**
# ```
# list : [90, 78, 71, 39, 19, 89, 92, 95, 70, 27]
# 3의 배수 개수 : 4
# 5의 배수 개수 : 3
# ```

# %%
import random

L = []
while len(L) < 10:
    num = random.randint(1, 100)
    L.append(num)

print('list :', L)

count3 = 0
count5 = 0
for n in L:
    if n % 3 == 0:
        count3 += 1
    if n % 5 == 0:
        count5 += 1

print('3의 배수 개수 :', count3)
print('5의 배수 개수 :', count5)
# Out:
# list : [85, 33, 55, 44, 45, 8, 11, 50, 85, 57]
# 3의 배수 개수 : 3
# 5의 배수 개수 : 5

# %% [markdown]
# ---
# ### q2.py — 합이 20 넘을 때 중지, 중간값 출력
#
# **문제**
# 10보다 작은 정수 N을 계속 입력받아 리스트에 저장한다. 리스트 안의 숫자의 합이 20보다 커지면 중지하고, 리스트의 개수와 중간에 위치한 수를 출력하시오.
# - 개수가 11개이면 6번째(인덱스 5), 개수가 10개이면 5번째(인덱스 4) → 개수 // 2 번째

# %%
L = []

while sum(L) < 20:
    n = int(input("10보다 작은 정수를 입력하세요 : "))
    L.append(n)

print("개수  : ", len(L))
print("중간값 : ", L[len(L)//2])
# Out:
# 개수  :  4
# 중간값 :  7

# %% [markdown]
# ---
#
# ### q3.py — 과일 리스트 + 길이 리스트 동시 갱신
#
# **문제**
# 과일 이름을 입력받아 리스트에 계속 추가한다. 과일 이름 리스트와 함께 각 이름의 길이 리스트도 관리한다. 두 리스트를 계속 출력하며, 3개 입력 시 종료하시오.

# %%
fruits = []
lengths = []

for i in range(3):
    name = input('과일 이름: ')
    fruits.append(name)
    lengths.append(len(name))
    print('과일:', fruits)
    print('길이:', lengths)
# Out:
# 과일: ['apple']
# 길이: [5]
# 과일: ['apple', 'banana']
# 길이: [5, 6]
# 과일: ['apple', 'banana', 'grapes']
# 길이: [5, 6, 6]

# %% [markdown]
# ## Quiz 7
#
# ---
#
# ### q1.py — 중복 없는 random 리스트에서 짝수만 추출
#
# **문제**
# random number(1~20)를 10개 뽑아 리스트를 만든다. 이때 중복된 수는 포함시키지 않는다. 이후 짝수만 모아 새로운 리스트를 출력하시오.

# %%
import random

num_list = []

while len(num_list) < 10 :
    n = random.randint(1,20)
    if n % 2 == 0 and n not in num_list:
        num_list.append(n)

print(num_list)
# Out:
# [10, 8, 20, 14, 4, 6, 2, 18, 12, 16]

# %% [markdown]
# ---
#
# ### q2.py — 두 리스트 모두에 없는 원소 찾기
#
# **문제**
# random number(1~30)로 구성된 중복 없는 리스트 A, B를 각각 10개씩 생성한다. 1~30 중 A와 B 둘 다에 속하지 않는 원소들로 리스트 C를 만드시오.

# %%
import random

A = []
while len(A) < 10:
    n = random.randint(1, 30)
    if n not in A:
        A.append(n)

B = []
while len(B) < 10:
    n = random.randint(1, 30)
    if n not in B:
        B.append(n)

print("A : ", A)
print("B : ", B)

C = []

for i in range(1,31):
    if i not in A and i not in B:
        C.append(i)

print("C : ", C)
# Out:
# A :  [11, 9, 30, 28, 13, 6, 22, 29, 14, 26]
# B :  [5, 24, 29, 13, 25, 30, 22, 17, 26, 11]
# C :  [1, 2, 3, 4, 7, 8, 10, 12, 15, 16, 18, 19, 20, 21, 23, 27]

# %% [markdown]
# ---
#
# ### q3.py — 길이 5 이상 문자열만 [문자열, 길이] 형태로
#
# **문제**
# ```python
# words = ['apple', 'kiwi', 'banana', 'pear', 'grape']
# ```
# 각 문자열의 길이를 구하여 길이가 5 이상인 문자열만 `[문자열, 길이]` 형태의 새로운 리스트를 생성하시오.
#
# **실행 예시**
# ```
# result : [['apple', 5], ['banana', 6], ['grape', 5]]
# ```

# %%
words = ['apple', 'kiwi', 'banana', 'pear', 'grape']

result = []
for w in words:
    if len(w) >= 5:
        result.append([w, len(w)])

print('result :', result)
# Out:
# result : [['apple', 5], ['banana', 6], ['grape', 5]]

# %% [markdown]
# ---
#
# ## Quiz 8
#
# ---
#
# ### q1.py — 약수의 합 함수
#
# **문제**
# 임의의 숫자 n이 주어지면 자기자신 포함 모든 약수의 합을 출력하는 프로그램을 작성하시오.
# - 약수를 구하고 합을 return하는 함수 `divisor(n)` 작성
# - 출력은 함수 밖에서 할 것
# **실행 예시**
# ```
# 6의 약수: (1, 2, 3, 6) → 합: 12
# ```

# %%
n = int(input("숫자를 입력하세요 : "))

def divisor(n):
    sum = 0
    for i in range(1, n+1):
        if n % i == 0 :
            sum+=i
    
    return sum

print(divisor(n))
# Out:
# 18

# %% [markdown]
# ---
# ### q2.py — Euclidean distance 함수
#
# **문제**
# 좌표 2개 (x1, y1), (x2, y2)를 입력받아 Euclidean distance를 구하시오.
# - 함수 `euclidian(x1, y1, x2, y2)` 작성, 계산 결과를 return
# - 거리는 소수 둘째자리까지 출력
# - 출력은 함수 밖에서 할 것
# **공식**: `((x1 - x2)**2 + (y1 - y2)**2) ** 0.5`

# %%
def euclidian(x1, y1, x2, y2):
    return ((x1 - x2)**2 + (y1 - y2)**2) ** 0.5

x1, y1 = map(int, input("좌표를 입력하세요").split())
x2, y2 = map(int, input("좌표를 입력하세요").split())

print("(%d, %d), (%d, %d) 유클리드 거리 : %.2f" %(x1, y1, x2, y2, euclidian(x1, y1, x2, y2)))
# Out:
# 10 20

# %% [markdown]
# ---
#
# ### q3.py — 홀수/짝수 판별 문자열 리스트 함수
#
# **문제**
# random number(1~99) 10개 리스트 L을 만들고, 각 숫자가 홀수인지 짝수인지 판별해 "odd"/"even" 문자열 리스트를 출력하시오.
# - 함수 `makelist(L)`: L을 받아 "odd"/"even" 리스트 A를 return
# - 출력은 함수 밖에서 할 것
# **실행 예시**
# ```
# L = [16, 59, 55, 39, 36, 33, 96, 20, 93, 73]
# A = ['even', 'odd', 'odd', 'odd', 'even', 'odd', 'even', 'even', 'odd', 'odd']
# ```

# %%
import random

def makelist(L):
    A = []
    for n in L:
        if n % 2 == 1:
            A.append('odd')
        else:
            A.append('even')
    return A

L = []
for i in range(10):
    L.append(random.randint(1, 99))

A = makelist(L)
print('L =', L)
print('A =', A)
# Out:
# L = [94, 28, 19, 18, 18, 63, 84, 16, 60, 70]
# A = ['even', 'even', 'odd', 'even', 'even', 'odd', 'even', 'even', 'even', 'even']

# %%
import random

def make_random_list():
    L = []
    while len(L) < 5:
        n = random.randint(1, 100)
        if n not in L:
            L.append(n)
    return L

def bigger(a, b):
    if a >= b:
        return a
    else:
        return b

L = make_random_list()
print('리스트:', L)

maximum = L[0]
for i in range(1, len(L)):
    maximum = bigger(maximum, L[i])

print('최대값:', maximum)

# %% [markdown]
# ---
#
# ## Quiz 9
#
# ---
#
# ### q1.py — 중복 없는 5개 random, max 찾기 (내장함수 금지)
#
# **문제**
# 1~100 사이 서로 다른 정수 5개를 생성한 후 가장 큰 숫자를 출력하시오.
# - `max()`, `sort()` 등 내장함수 사용 금지
# - 함수 1: 중복 없는 random 숫자 5개 생성 후 리스트 return
# - 함수 2: 숫자 두 개를 받아 더 큰 값 return

# %%
import random

def make_random_list():
    L = []
    while len(L) < 5:
        n = random.randint(1, 100)
        if n not in L:
            L.append(n)
    return L

def bigger(a, b):
    if a >= b:
        return a
    else:
        return b

L = make_random_list()
print('리스트:', L)

maximum = L[0]
for i in range(1, len(L)):
    maximum = bigger(maximum, L[i])

print('최대값:', maximum)
# Out:
# 리스트: [54, 39, 64, 12, 25]
# 최대값: 64

# %% [markdown]
# ---
#
# ### q2.py — 모음/자음 출력 함수
#
# **문제**
# 문자열을 입력받아, 모음(a, e, i, o, u)은 그대로, 자음은 '-'로 출력하시오.
# - 함수: 문자열을 순서대로 확인해 모음이면 출력하고 아니면 '-' 출력, 모음의 개수를 return
# **실행 예시**
# ```
# Input string : apple
# a - - - e
# Count : 2
# ```

# %%
def check_str(s):
    vowels = 'aeiou'
    cnt = 0
    for i in s:
        if i in vowels:
            print(i, end = ' ')
            cnt+=1
        else:
            print('-', end =' ')
    
    return cnt

strr = input("문자열을 입력하세요")
print(check_str(strr))
# Out:
# a - - - e 2

# %% [markdown]
# ---
#
# ### q3.py — 재귀함수로 2의 n제곱
#
# **문제**
# 정수 n을 입력받아 2의 n제곱 값을 출력하시오.
# - 재귀함수를 이용하여 제곱값을 구하고 return하는 함수 작성
# **실행 예시**
# ```
# Input number : 5
# 32
# ```

# %%
def square(n):
    return 2 ** n

num = int(input("Input number : "))
print(square(num))
# Out:
# 32

# %% [markdown]
# ## Quiz 10
#
# ---
#
# ### q1.py — dictionary 평균 성적 계산
#
# **문제**
# 아래 학생 점수 dictionary에서 각 학생의 평균 점수를 계산하여 출력하시오.
# 단, for문과 dictionary 관련 메소드를 사용한다.
#
# **주어진 데이터**
# ```python
# score = {
#     'Kim' : [80, 90],
#     'Lee' : [70, 85],
#     'Park': [100, 95]
# }
# ```
#
# **실행 예시**
# ```
# Kim 평균 : 85.0
# Lee 평균 : 77.5
# Park 평균 : 97.5
# ```

# %%
score = {
    'Kim' : [80, 90],
    'Lee' : [70, 85],
    'Park': [100, 95]
}

for n,s in score.items():
    avg = sum(s)/2
    print("%s 평균 : %.1f" %(n,avg))
# Out:
# Kim 평균 : 85.0
# Lee 평균 : 77.5
# Park 평균 : 97.5

# %% [markdown]
# ---
#
# ### q2.py — set으로 공통 문자 / Y에만 있는 문자 찾기
#
# **문제**
# ```python
# X = 'python'
# Y = 'programming'
# ```
# X와 Y에 공통으로 있는 문자를 중복 없이 출력하고, X에는 없고 Y에만 있는 문자를 중복 없이 출력하시오. (set 사용)
#
# **실행 예시**
# ```
# Common characters : {'o', 'p', 'n'}
# Characters only in Y : {'g', 'r', 'm', 'a', 'i'}
# ```

# %%
X = 'python'
Y = 'programming'

set_x = set(X)
set_y = set(Y)

print("Common characters : ", set_x & set_y)
print("Characters only in Y : ", set_y - set_x)
# Out:
# Common characters :  {'o', 'p', 'n'}
# Characters only in Y :  {'m', 'i', 'a', 'g', 'r'}

# %% [markdown]
# ---
#
# ## Quiz 11
#
# ---
#
# ### q1.py — zip으로 dictionary 만들고 메뉴 검색
#
# **문제**
# 두 리스트를 zip으로 연결하여 dictionary를 만들고, 사용자에게 메뉴 이름을 입력받아 가격을 출력하시오.
# 1. 입력한 메뉴가 없으면 "없는 메뉴입니다" 출력
# 2. 가격이 10000원 이상이면 "비싼 메뉴입니다." 추가 출력
# **주어진 데이터**
# ```python
# menu  = ['햄버거', '피자', '치킨', '라면']
# price = [5000, 12000, 18000, 4000]
# ```
#
# **실행 예시**
# ```
# 메뉴 입력 : 햄버거
# 가격 : 5000 원
#
# 메뉴 입력 : 피자
# 가격 : 12000 원
# 비싼 메뉴입니다.
#
# 메뉴 입력 : 제육
# 없는 메뉴입니다
# ```

# %%
menu  = ['햄버거', '피자', '치킨', '라면']
price = [5000, 12000, 18000, 4000]


menu_dic = dict(zip(menu, price))
print(menu_dic)

user = input("메뉴 이름을 입력하세요 ")
if user in menu_dic.keys():
    print("가격 : ", menu_dic[user])
else: 
    print("없는 메뉴입니다.")
# Out:
# {'햄버거': 5000, '피자': 12000, '치킨': 18000, '라면': 4000}
# 가격 :  5000

# %% [markdown]
# ---
#
# ### q2.py — X에는 있고 Y에는 없는 문자 (for loop, 중복 제거)
#
# **문제**
# ```python
# X = ['A', 'B', 'C', 'D', 'B', 'D', 'E']
# Y = ['B', 'C', 'F', 'G', 'D', 'H']
# ```
# X에는 존재하지만 Y에는 존재하지 않는 문자만 출력하시오.
# - set 사용 금지, for loop 직접 구현
# - 중복 제거 후 출력
# **실행 예시**
# ```
# ['A', 'E']
# ```

# %%
X = ['A', 'B', 'C', 'D', 'B', 'D', 'E']
Y = ['B', 'C', 'F', 'G', 'D', 'H']

result = []
for v in X:
    if v not in Y and v not in result:
        result.append(v)

print(result)
# Out:
# ['A', 'E']

# %% [markdown]
# ---
#
# ### q3.py — 특수기호 제거 후 단어 리스트 만들기
#
# **문제**
# ```python
# string = "I like python and I like programming!"
# ```
# 위 string에서 특수기호를 제거하고 모든 문자를 소문자로 변환한다. 이후 `split()`을 사용하여 단어(word) 리스트를 만드시오.
#
# **실행 예시**
# ```
# Lower String : i like python and i like programming!
# Character String : i like python and i like programming
# Word List : ['i', 'like', 'python', 'and', 'i', 'like', 'programming']
# ```

# %%
string = "I like python and I like programming!"

new_string = string.lower()
cstring = ''.join(c for c in new_string if c.isalpha() or c.isspace())
wlist = cstring.split()

print("Word List : ", wlist)
# Out:
# Word List :  ['i', 'like', 'python', 'and', 'i', 'like', 'programming']

# %% [markdown]
# ---
#
# ## Quiz 12
#
# ---
#
# ### q1.py — 단어의 첫 두 글자로 벡터 만들기
#
# **문제**
# 단어의 첫 글자와 두번째 글자를 이용해 간단한 벡터를 만드시오.
# - 알파벳 변환: a=1, b=2, c=3, ..., z=26
# - word vector = [첫 글자 번호, 두번째 글자 번호]
# - 단어 하나를 입력받고 벡터를 출력 (Normalize 하지 않음)
# **실행 예시**
# ```
# Input Word : trains
# Word Vector : [20, 18]
# ```
# (t=20, r=18)

# %%
word = input("단어를 입력하세요 : ")

word_f = ord(word[0]) - ord('a') + 1
word_l = ord(word[-1]) - ord('a') + 1
print('[%d, %d]' %(word_f, word_l))
# Out:
# [20, 14]

# %% [markdown]
# ---
#
# ### q2.py — 성장 점수 최대 학생 찾기
#
# **문제**
# 중간고사 점수, 기말고사 점수, 공부시간이 기록되어 있다. 각 학생의 성장 점수(기말 - 중간)를 계산하고, 가장 많이 성장한 학생과 해당 학생의 공부 시간을 출력하시오.
#
# **주어진 데이터**
# ```python
# score = {'Lee': [70, 85], 'Kim': [60, 95], 'Park': [80, 90]}
# hours = {'Lee': 300, 'Kim': 500, 'Park': 200}
# ```
#
# **실행 예시**
# ```
# Most Improved Student : Kim
# Growth Score : 35
# Study Hours : 500
# ```

# %%
score = {'Lee': [70, 85], 'Kim': [60, 95], 'Park': [80, 90]}
hours = {'Lee': 300, 'Kim': 500, 'Park': 200}

max_score = 0
mas_score_name = ''

for n,s in score.items():
    avg = s[1]-s[0]
    if avg > max_score :
        max_score = avg
        max_score_name = n
    

print("Most Improved Student : ", max_score_name)
print("Growth Score : ", max_score)
print("Study Hours : ", hours[max_score_name])
# Out:
# Most Improved Student :  Kim
# Growth Score :  35
# Study Hours :  500
